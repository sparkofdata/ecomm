# %%
dbutils.widgets.text("Job ID", "1031", "job_id")
dbutils.widgets.dropdown("File-Type", "837P", ["837P", "837I"], "File_Type")
dbutils.widgets.dropdown("States", "KY" ,["KY", "IL", "NY"], "State")

# %%
print(dbutils.widgets.get("job_id"))
print(dbutils.widgets.get("File_Type"))
print(dbutils.widgets.get("State"))
